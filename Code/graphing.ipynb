# %%
import pandas as pd
from plotly import express as px

df= pd.read_csv("../history.csv")

# %%
data = df.rolling(window=200).mean()

#plt.plot(data=data, )

# %%
px.scatter(data_frame=data, y=['random',"reward", "progress"] ,  )
